# %% [markdown]
# WORKING WITH IMAGES

# %%
from PIL import Image

# %%
mac = Image.open('example.jpg')

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x124 at 0x1C110E61700>

# %%
mac.size
# Out:
# (474, 124)

# %%
mac.filename
# Out:
# 'example.jpg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %% [markdown]
# Cropping Images

# %%
mac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1C111108340>

# %%
pencils = Image.open('pencils.jpg')

# %%
pencils
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=391x294 at 0x1C11112A520>

# %%
pencils.size
# Out:
# (391, 294)

# %%
x = 0
y = 0

w = 313/2
h = 307/4

# %%
pencils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=156x77 at 0x1C111178460>

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x124 at 0x1C110E61700>

# %%
mac.size
# Out:
# (474, 124)

# %%
halfway = 474/2

# %%
x = halfway -50
w = halfway + 50

# %%
y = 240
h = 124

# %%
red = Image.open('red.jpg')

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x632 at 0x1C11112AC10>

# %%
red.putalpha(128)

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=474x632 at 0x1C11112AC10>
